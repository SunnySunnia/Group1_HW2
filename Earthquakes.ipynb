# %% [markdown]
# # Choosing the Live Feed

# %% [markdown]
# We first need to choose a relevant feed for study. If we wanted to choose another feed, we could just copy and paste a different URL into the url variable.

# %%
import urllib
import json
import pandas as pd
from pprint import pprint

url = 'http://earthquake.usgs.gov/earthquakes/feed/v1.0/summary/1.0_week.geojson'

# %% [markdown]
# We use the code below to look at the structure of the JSON data.

# %%
d = json.loads(urllib.urlopen(url).read())

data = pd.DataFrame(d.items())

data
# Out:
#           0                                                  1
# 0      type                                  FeatureCollection
# 1  features  [{u'geometry': {u'type': u'Point', u'coordinat...
# 2      bbox  [-179.4843, -56.4946, -3.1, 179.0595, 66.7659,...
# 3  metadata  {u'status': 200, u'count': 1113, u'title': u'U...

# %% [markdown]
# We can see that the data is stored in a dictionary.

# %%
data[1][1][0]
# Out:
# {u'geometry': {u'coordinates': [-121.3182, 36.8353, 6.5], u'type': u'Point'},
#  u'id': u'nc72091686',
#  u'properties': {u'alert': None,
#   u'cdi': None,
#   u'code': u'72091686',
#   u'detail': u'http://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/nc72091686.geojson',
#   u'dmin': 0.06288207,
#   u'felt': None,
#   u'gap': 194.4,
#   u'ids': u',nc72091686,',
#   u'mag': 1.1,
#   u'magType': u'Md',
#   u'mmi': None,
#   u'net': u'nc',
#   u'nst': None,
#   u'place': u'4km ENE of Ridgemark, California',
#   u'rms': 0.02,
#   u'sig': 19,
#   u'sources': u',nc,',
#   u'status': u'AUTOMATIC',
#   u'time': 1382308262500,
#   u'title': u'M 1.1 - 4km ENE of Ridgemark, California',
#   u'tsunami': None,
#   u'type': u'earthquake',
#   u'types': u',general-link,geoserve,nearby-cities,origin,phase-data,',
#   u'tz': -420,
#   u'updated': 1382308360895,
#   u'url': u'http://earthquake.usgs.gov/earthquakes/eventpage/nc72091686'},
#  u'type': u'Feature'}

# %% [markdown]
# We can thus write code to extract the desired values from the dictionary.

# %%
earthquakes = []

for categories in data[1][1]:
    
    src = categories['properties']['net']
    code = categories['properties']['code']
    time = categories['properties']['time']
    longitude = categories['geometry']['coordinates'][1]
    latitude = categories['geometry']['coordinates'][0]
    magnitude = categories['properties']['mag']
    depth = categories['geometry']['coordinates'][2]
    nst = categories['properties']['nst']
    place = categories['properties']['place']
    earthquake_columns = [src, code, time, longitude, latitude, magnitude, depth, nst, place]
    
    earthquakes.append(earthquake_columns)

#earthquakes

df = pd.DataFrame(np.array(earthquakes),
 columns = ['Src','Code','Time','Latitude','Longitude','Magnitude','Depth','Nst','Place'])
df[0:20]
# Out:
#    Src      Code           Time Latitude Longitude Magnitude  Depth   Nst  \
# 0   nc  72091686  1382308262500  36.8353 -121.3182       1.1    6.5  None
# 1   us  b000khpg  1382305892240 -18.6391  -70.0963       4.5  76.61  None
# 2   nc  72091676  1382305508200  37.4732  -118.979       1.5    3.9  None
# 3   hv  60579886  1382305480200   19.395 -155.2865       2.7    6.4  None
# 4   hv  60579891  1382305467400  19.1987 -155.6105       3.5    0.6  None
# 5   ci  11381354  1382305317800  33.6807 -116.6797         1   19.9    20
# 6   ak  10827316  1382303919000   61.746 -152.0249       2.1    100  None
# 7   ci  11381338  1382301360000  35.6697 -118.4677       1.4    9.6    11
# 8   ak  10827304  1382300797000  62.1046 -152.5981       1.4   51.8  None
# 9   ak  10827299  1382300507000  61.6809 -151.0288       1.8   49.5  None
# 10  ak  10827296  1382300419000  60.0634 -140.5906       2.4    5.1  None
# 11  us  b000khnw  1382298305380  35.7836   77.4106       5.4  75.29  None
# 12  ak  10827287  1382298138000  63.1862 -149.8679         1   85.9  None
# 13  us  b000khnn  1382297405200   13.025  144.7346       4.6  51.68  None
# 14  us  b000khnk  1382297058150  -6.3979  147.7712       4.8  77.82  None
# 15  us  b000khnc  1382294888080  -6.4779  155.0119       5.1  71.57  None
# 16  ak  10827267  1382294667000  59.2058 -153.2031       3.3      2  None
# 17  ci  11381330  1382294569600  33.6512  -116.744         1     16    18
# 18  pr  13293004  1382293978400  17.8349  -66.9568       2.6      4    16
# 19  ci  11381322  1382293767000  32.5243 -115.6707       1.5    7.7    13
#
#                                         Place
# 0            4km ENE of Ridgemark, California
# 1                     28km SE of Arica, Chile
# 2         19km S of Mammoth Lakes, California
# 3                   6km SW of Volcano, Hawaii
# 4                    13km W of Pahala, Hawaii
# 5            7km SSE of Idyllwild, California
# 6                   104km W of Willow, Alaska
# 7      4km SSW of Wofford Heights, California
# 8                131km W of Talkeetna, Alaska
# 9                    52km W of Willow, Alaska
# 10                 75km NW of Yakutat, Alaska
# 11                  113km NNE of Thang, India
# 12               51km WSW of Cantwell, Alaska
# 13           27km S of Inarajan Village, Guam
# 14  25km NNW of Finschhafen, Papua New Guinea
# 15      55km WSW of Panguna, Papua New Guinea
# 16           100km SW of Anchor Point, Alaska
# 17  10km S of Idyllwild-Pine Cove, California
# 18           15km SSW of Guanica, Puerto Rico
# 19                10km SW of Progreso, Mexico

# %% [markdown]
# This should print out the unique places with earthquakes

# %%
set(df.Src)
# Out:
# set([u'pr',
#      u'ci',
#      u'nm',
#      u'nn',
#      u'mb',
#      u'uu',
#      u'ak',
#      u'nc',
#      u'hv',
#      u'us',
#      u'uw',
#      u'se'])

# %% [markdown]
# Let's look at California

# %%
california = df[df.Src=='ci']
california[0:5]
print california.Longitude[0:5]
california.Latitude[0:5]
# Out:
# 5    -116.6797
# 7    -118.4677
# 17    -116.744
# 19   -115.6707
# 23   -116.3943
# Name: Longitude
# 5     33.6807
# 7     35.6697
# 17    33.6512
# 19    32.5243
# 23     33.039
# Name: Latitude

# %%
from mpl_toolkits.basemap import Basemap

def G1_quakes(abbr):      #abr=abbreviation of the state
    state = df[df.Src == abbr]     #subseting the earthquakes in a specific state
    
    #setting coordinates for displaying the state:
    lllon=-(min(max(abs(state.Longitude))+5,180))          
        #there has been a problem of simply using the minimum of the logitudes for Alaska because the eastmost location has 
        #logitude on the east atmosphere (E 173), which is positive whereas all locations of other states are negative.
        #to solve this, take the max of the absolute values of Lon. the times '-1', also dont want it to exceed -180.
    lllat=min(state.Latitude)-5
    urlon=-(min(abs(state.Longitude))-5)
    urlat=max(state.Latitude)+5
    
    #Basemap:
    fig = plt.figure(figsize=(8,8))
    m = Basemap(llcrnrlon=lllon, llcrnrlat=lllat,
                urcrnrlon=urlon,urcrnrlat=urlat,
                resolution='l', area_thresh=1000.,projection='merc')
    m.drawcoastlines()
    m.drawcountries()
    m.drawstates()
    m.fillcontinents(color='coral', lake_color='aqua')
    m.drawmapboundary(fill_color='aqua')
    
    #plotting the earthquakes as dots with different sizes proportional to magnitudes:
    lon = state.Longitude  
    lat = state.Latitude
    xpt,ypt = m(lon,lat)
    lonpt, latpt = m(xpt,ypt,inverse=True)
    sizes=state.Magnitude
    for i in range(1,len(lon)):
        m.plot(xpt[i-1:i],ypt[i-1:i],'ro',markersize=sizes[i-1:i]*5,alpha=0.7)
    plt.show()

# %%
abbr='ci'
#can input any state abbreviations, like ak, hv, pr, nn.....
m1=G1_quakes(abbr)
